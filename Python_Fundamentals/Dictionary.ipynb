# %%
#key - value pairing

# %%
imbd_dictionary = {"abc": 4.5, "ABC": 2}

# %%
type(imbd_dictionary)
# Out:
# dict

# %%
imbd_dictionary.keys()
# Out:
# dict_keys(['abc', 'ABC'])

# %%
list(imbd_dictionary)
# Out:
# ['abc', 'ABC']

# %%
list(imbd_dictionary.values())
# Out:
# [4.5, 2]

# %%
imbd_dictionary["abc"] = 5

# %%
imbd_dictionary
# Out:
# {'abc': 5, 'ABC': 2}

# %%
imbd_dictionary["gng"] = 4.7

# %%
imbd_dictionary
# Out:
# {'abc': 5, 'ABC': 2, 'gng': 4.7}

# %%
imbd_dictionary.get("gng",0)
# Out:
# 4.7

# %%
imbd_dictionary.get("gn",0)
# Out:
# 0

# %%
example = {"k1": 10,"k2": [10,20,30],"k3": {"a":4,"b":5}}

# %%
example["k3"]["b"]
# Out:
# 5

# %%
example["k2"][1]
# Out:
# 20
