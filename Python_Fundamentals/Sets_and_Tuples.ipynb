# %% [markdown]
# ### Sets

# %%
sampleList = [10,20,30,10,20,40,10,20,40]

# %%
len(sampleList)
# Out:
# 9

# %%
mySet = set(sampleList)

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet = {10,20,30,10,20,40,10,20,40}

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet2 = {30,40,50,60}

# %%
mySet.intersection(mySet2)
# Out:
# {30, 40}

# %%
len(set(sampleList)) # for example checking how many countries we made sales to today
# Out:
# 4

# %%
emptyList = list() # or emptyList = {}

# %%
emptyList.append(10)
emptyList.append(20)
emptyList.append(30)

# %%
emptySet = set() # because emptySet = {} is dict

# %%
type(emptySet)
# Out:
# set

# %%
len(emptySet)
# Out:
# 0

# %%
emptySet.add(10)
emptySet.add(10)
emptySet.add(10)

# %%
emptySet
# Out:
# {10}

# %% [markdown]
# ### Tuples

# %%
# like sets but immutable

# myTuple[0] = 100 you can't do this.

# %%
myTuple = (10,20,20,"a",(2,3,2))

# %%
myTuple.count(20)
# Out:
# 2

# %%
myTuple.index("a")
# Out:
# 3
