# %%
myString = "Eylul Bencik"

# %%
myString.split()
# Out:
# ['Eylul', 'Bencik']

# %%
type(myString.split())
# Out:
# list

# %%
# list

# %%
# myString = " yagiz " : you can do this but, 
# myString[0] = "Y"    : you can't change just one element.

# %%
x = 10
y = "hi"
z = 13.4

# %%
sampleList = [x,y,z]

# %%
sampleList
# Out:
# [10, 'hi', 13.4]

# %%
# mutability

sampleList[0] = 35

# %%
sampleList
# Out:
# [35, 'hi', 13.4]

# %%
listt = [1,2,2,2,5,6,7]

# %%
len(listt)
# Out:
# 7

# %%
# .count(value): counts how many times the specified value appears in the list.
# .index(2):  shows first two.

listt.count(2) # output: 3
listt.index(2)
# Out:
# 1

# %%
# like scanf

x = input("Enter x: ")
# Out:
# Enter x:  2

# %%
y = input("Enter y: ")
# Out:
# Enter y:  4

# %%
type(x) # because property of python
# Out:
# str

# %%
inputList = []

# %%
# .append()

inputList.append(x)
inputList.append(y)

# %%
inputList
# Out:
# ['2', '4']

# %%
# TYPE CASTING

# we do that because lists assume elements as str
inputList[0] * 2
# Out:
# '22'

# %%
int(inputList[0]) * 2 
# it works for integer string
# 2 * 2 = 4
# Out:
# 4

# %%
# for python

list1 = [3,4,5]
list2 = [6,7,8]
list1 + list2
# Out:
# [3, 4, 5, 6, 7, 8]

# %%
# in python

list1 * 2
# Out:
# [3, 4, 5, 3, 4, 5]

# %%
nestedList = [1,2,"abc",'gad',[1,2,3]]
smallList = nestedList[-1] # last element

smallList
# Out:
# [1, 2, 3]

# %%
smallList[1]
# Out:
# 2

# %%
nestedList[-1][2]
# Out:
# 3

# %%
# slicing

exmpList = [ 4,5,6,7,8,9,10]

exmpList[1:-2:]
# Out:
# [5, 6, 7, 8]
