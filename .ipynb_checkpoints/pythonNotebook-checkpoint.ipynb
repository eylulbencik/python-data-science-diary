# %%
# camelCase
# snake_case

# %%
temp = 20
abc = 20.45
type(temp)
# Out:
# int

# %%
type(abc)
# Out:
# float

# %%
type(40/4) # int/int = float ( just pythonda )
# Out:
# float

# %%
# ** and // and % 

2 ** 5 #must be 32
100 // 3 # must be 33
10 % 4 # must be 2
# Out:
# 2

# %%
 name = "eylul bencik"

# %%
name.upper()
# Out:
# 'EYLUL BENCIK'

# %%
len( name )
# Out:
# 12

# %%
print("hello \ncanim")
# Out:
# hello
# canim

# %%
name[0]
# Out:
# 'e'

# %%
name[ len(name) - 1 ] # son harf ya da !!!! name[-1] name[-3]=c
# Out:
# 'k'

# %%
barcode = "ABCDEFG8234u12"
barcode[3::] # D den başlar.
barcode[:3:] # ABC
barcode[::2] # ACEG..

barcode[::-1] # stepping size -1 olursa string ters çevrilir.
# Out:
# '21u4328GFEDCBA'
